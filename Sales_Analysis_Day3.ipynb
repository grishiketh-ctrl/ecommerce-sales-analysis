# %% [markdown]
# <a href="https://colab.research.google.com/github/grishiketh-ctrl/ecommerce-sales-analysis/blob/main/Sales_Analysis_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = {
    "Date": [
        "2026-01-05",
        "2026-01-08",
        "2026-01-12",
        "2026-02-03",
        "2026-02-10",
        "2026-02-15",
        "2026-03-02",
        "2026-03-08",
        "2026-03-20",
        "2026-03-25"
    ],

    "Product": [
        "Laptop",
        "Phone",
        "Headphones",
        "Laptop",
        "Phone",
        "Tablet",
        "Headphones",
        "Laptop",
        "Phone",
        "Tablet"
    ],

    "Region": [
        "South",
        "North",
        "South",
        "East",
        "North",
        "South",
        "East",
        "South",
        "West",
        "East"
    ],

    "Quantity": [
        2, 3, 5, 1, 4,
        2, 6, 3, 2, 4
    ],

    "Price": [
        50000, 20000, 3000, 50000, 20000,
        25000, 3000, 50000, 20000, 25000
    ]
}

# %%
df.head()
# Out:
#          Date     Product Region  Quantity  Price
# 0  2026-01-05      Laptop  South         2  50000
# 1  2026-01-08       Phone  North         3  20000
# 2  2026-01-12  Headphones  South         5   3000
# 3  2026-02-03      Laptop   East         1  50000
# 4  2026-02-10       Phone  North         4  20000

# %%
df.shape
df.columns
# Out:
# Index(['Date', 'Product', 'Region', 'Quantity', 'Price'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      10 non-null     object
#  1   Product   10 non-null     object
#  2   Region    10 non-null     object
#  3   Quantity  10 non-null     int64
#  4   Price     10 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Revenue"] = df["Quantity"] * df["Price"]

# %%
average_revenue = df["Revenue"].mean()

print("Average Revenue:", average_revenue)
# Out:
# Average Revenue: 66300.0

# %%
product_sales = df.groupby("Product")["Revenue"].sum()

print(product_sales)
# Out:
# Product
# Headphones     33000
# Laptop        300000
# Phone         180000
# Tablet        150000
# Name: Revenue, dtype: int64

# %%
region_sales = df.groupby("Region")["Revenue"].sum()

print(region_sales)
# Out:
# Region
# East     168000
# North    140000
# South    315000
# West      40000
# Name: Revenue, dtype: int64

# %%
df = pd.DataFrame(data)

print(df)
# Out:
#          Date     Product Region  Quantity  Price
# 0  2026-01-05      Laptop  South         2  50000
# 1  2026-01-08       Phone  North         3  20000
# 2  2026-01-12  Headphones  South         5   3000
# 3  2026-02-03      Laptop   East         1  50000
# 4  2026-02-10       Phone  North         4  20000
# 5  2026-02-15      Tablet  South         2  25000
# 6  2026-03-02  Headphones   East         6   3000
# 7  2026-03-08      Laptop  South         3  50000
# 8  2026-03-20       Phone   West         2  20000
# 9  2026-03-25      Tablet   East         4  25000
